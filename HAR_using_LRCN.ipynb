# %%
# Import the required libraries.
import os
import cv2
import math
import random
import numpy as np
import datetime as dt
import tensorflow as tf
from collections import deque
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model
import pickle

# %%
import tensorflow as tf

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
seed_constant = 27
np.random.seed(seed_constant)
random.seed(seed_constant)
tf.random.set_seed(seed_constant)

# %%
# Specify the height and width to which each video frame will be resized in our dataset.
IMAGE_HEIGHT , IMAGE_WIDTH = 64, 64

# Specify the number of frames of a video that will be fed to the model as one sequence.
SEQUENCE_LENGTH = 25

# Specify the directory containing the dataset. 
DATASET_DIR = "Human_Activity_Recognition_Video_Dataset"

CLASSES_LIST = sorted([entry.name for entry in os.scandir(DATASET_DIR) if entry.is_dir()])

# %%
CLASSES_LIST
# Out:
# ['Clapping',
#  'Meet and Split',
#  'Sitting',
#  'Standing Still',
#  'Walking',
#  'Walking While Reading Book',
#  'Walking While Using Phone']

# %%
# Create a Matplotlib figure and specify the size of the figure.
plt.figure(figsize = (20, 20))

all_classes_names = os.listdir(DATASET_DIR)

random_range = random.sample(range(len(all_classes_names)), 7) 

# Iterating through all the generated random values.
for counter, random_index in enumerate(random_range, 1):

    # Retrieve a Class Name using the Random Index.
    selected_class_Name = all_classes_names[random_index]

    # Retrieve the list of all the video files present in the randomly selected Class Directory.
    video_files_names_list = os.listdir(f'{DATASET_DIR}/{selected_class_Name}')

    # Randomly select a video file from the list retrieved from the randomly selected Class Directory.
    selected_video_file_name = random.choice(video_files_names_list)

    # Initialize a VideoCapture object to read from the video File.
    video_reader = cv2.VideoCapture(f'{DATASET_DIR}/{selected_class_Name}/{selected_video_file_name}')
    
    # Read the first frame of the video file.
    _, bgr_frame = video_reader.read()

    # Release the VideoCapture object. 
    video_reader.release()

    # Convert the frame from BGR into RGB format. 
    rgb_frame = cv2.cvtColor(bgr_frame, cv2.COLOR_BGR2RGB)

    # Write the class name on the video frame.
    cv2.putText(rgb_frame, selected_class_Name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
    
    # Display the frame.
    plt.subplot(5, 4, counter);plt.imshow(rgb_frame);plt.axis('off')

# %%
def frames_extraction(video_path):
    '''
    This function will extract the required frames from a video after resizing and normalizing them.
    Args:
        video_path: The path of the video in the disk, whose frames are to be extracted.
    Returns:
        frames_list: A list containing the resized and normalized frames of the video.
    '''

    # Declare a list to store video frames.
    frames_list = []
    
    # Read the Video File using the VideoCapture object.
    video_reader = cv2.VideoCapture(video_path)

    # Get the total number of frames in the video.
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calculate the the interval after which frames will be added to the list.
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH), 1)

    # Iterate through the Video Frames.
    for frame_counter in range(SEQUENCE_LENGTH):

        # Set the current frame position of the video.
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)

        # Reading the frame from the video. 
        success, frame = video_reader.read() 

        # Check if Video frame is not successfully read then break the loop
        if not success:
            break

        # Resize the Frame to fixed height and width.
        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))
        
        # Normalize the resized frame by dividing it with 255 so that each pixel value then lies between 0 and 1
        normalized_frame = resized_frame / 255
        
        # Append the normalized frame into the frames list
        frames_list.append(normalized_frame)
    
    # Release the VideoCapture object. 
    video_reader.release()

    # Return the frames list.
    return frames_list

# %%
def create_dataset():
    '''
    This function will extract the data of the selected classes and create the required dataset.
    Returns:
        features:          A list containing the extracted frames of the videos.
        labels:            A list containing the indexes of the classes associated with the videos.
        video_files_paths: A list containing the paths of the videos in the disk.
    '''

    # Declared Empty Lists to store the features, labels and video file path values.
    features = []
    labels = []
    video_files_paths = []
    
    # Iterating through all the classes mentioned in the classes list
    for class_index, class_name in enumerate(CLASSES_LIST):
        
        # Display the name of the class whose data is being extracted.
        print(f'Extracting Data of Class: {class_name}')
        
        # Get the list of video files present in the specific class name directory.
        files_list = os.listdir(os.path.join(DATASET_DIR, class_name))
        
        # Counter to keep track of the number of videos extracted for each class
        video_count = 0
        
        # Iterate through all the files present in the files list.
        for file_name in files_list:
            
            # Get the complete video path.
            video_file_path = os.path.join(DATASET_DIR, class_name, file_name)

            # Extract the frames of the video file.
            frames = frames_extraction(video_file_path)

            # Check if the extracted frames are equal to the SEQUENCE_LENGTH specified above.
            # So ignore the vides having frames less than the SEQUENCE_LENGTH.
            if len(frames) == SEQUENCE_LENGTH:

                # Append the data to their repective lists.
                features.append(frames)
                labels.append(class_index)
                video_files_paths.append(video_file_path)
                
                # Increment the video count
                video_count += 1
                
                # if you want to extract all the videos from all the classes
                # then remove this check, im working with 15 videos from each class to save time

    # Converting the list to numpy arrays
    features = np.asarray(features)
    labels = np.array(labels)  
    
    # Return the frames, class index, and video file path.
    return features, labels, video_files_paths

# %%
# Create the dataset.
features, labels, video_files_paths = create_dataset()
# Out:
# Extracting Data of Class: Clapping
# Extracting Data of Class: Meet and Split
# Extracting Data of Class: Sitting
# Extracting Data of Class: Standing Still
# Extracting Data of Class: Walking
# Extracting Data of Class: Walking While Reading Book
# Extracting Data of Class: Walking While Using Phone

# %%
with open("feature.pickle","wb") as f:
    pickle.dump(features,f)
with open("labels.pickle","wb") as f:
    pickle.dump(labels,f)
with open("video_files_paths.pickle","wb") as f:
    pickle.dump(video_files_paths,f)

# %%
with open("feature.pickle","rb") as f:
    features=pickle.load(f)
with open("labels.pickle","rb") as f:
    labels=pickle.load(f)
with open("video_files_paths.pickle","rb") as f:
    video_files_paths=pickle.load(f)

# %%
# Using Keras's to_categorical method to convert labels into one-hot-encoded vectors
one_hot_encoded_labels = to_categorical(labels)

# %%
# Split the Data into Train ( 75% ) and Test Set ( 25% ).
features_train, features_test, labels_train, labels_test = train_test_split(features, one_hot_encoded_labels,
                                                                            test_size = 0.25, shuffle = True,
                                                                            random_state = seed_constant)

# %%
def plot_metric(model_training_history, metric_name_1, metric_name_2, plot_name):
    '''
    This function will plot the metrics passed to it in a graph.
    Args:
        model_training_history: A history object containing a record of training and validation 
                                loss values and metrics values at successive epochs
        metric_name_1:          The name of the first metric that needs to be plotted in the graph.
        metric_name_2:          The name of the second metric that needs to be plotted in the graph.
        plot_name:              The title of the graph.
    '''
    
    # Get metric values using metric names as identifiers.
    metric_value_1 = model_training_history.history[metric_name_1]
    metric_value_2 = model_training_history.history[metric_name_2]
    
    # Construct a range object which will be used as x-axis (horizontal plane) of the graph.
    epochs = range(len(metric_value_1))

    # Plot the Graph.
    plt.plot(epochs, metric_value_1, 'blue', label = metric_name_1)
    plt.plot(epochs, metric_value_2, 'red', label = metric_name_2)

    # Add title to the plot.
    plt.title(str(plot_name))

    # Add legend to the plot.
    plt.legend()

# %%
def create_LRCN_model():
    '''
    This function will construct the required LRCN model.
    Returns:
        model: It is the required constructed LRCN model.
    '''

    # We will use a Sequential model for model construction.
    model = Sequential()
    
    # Define the Model Architecture.
    ########################################################################################################################
    
    model.add(TimeDistributed(Conv2D(16, (3, 3), padding='same',activation = 'relu'),
                              input_shape = (SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)))
    
    model.add(TimeDistributed(MaxPooling2D((4, 4)))) 
    model.add(TimeDistributed(Dropout(0.25)))
    
    model.add(TimeDistributed(Conv2D(32, (3, 3), padding='same',activation = 'relu')))
    model.add(TimeDistributed(MaxPooling2D((4, 4))))
    model.add(TimeDistributed(Dropout(0.25)))
    
    model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same',activation = 'relu')))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    model.add(TimeDistributed(Dropout(0.25)))
    
    model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same',activation = 'relu')))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    #model.add(TimeDistributed(Dropout(0.25)))
                                      
    model.add(TimeDistributed(Flatten()))
                                      
    model.add(LSTM(32))
                                      
    model.add(Dense(len(CLASSES_LIST), activation = 'softmax'))

    ########################################################################################################################

    # Display the models summary.
    model.summary()
    
    # Return the constructed LRCN model.
    return model

# %%
# Construct the required LRCN model.
LRCN_model = create_LRCN_model()

# Display the success message.
print("Model Created Successfully!")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_12 (TimeD  (None, 25, 64, 64, 16)    448
#  istributed)
#
#  time_distributed_13 (TimeD  (None, 25, 16, 16, 16)    0
#  istributed)
#
#  time_distributed_14 (TimeD  (None, 25, 16, 16, 16)    0
#  istributed)
#
#  time_distributed_15 (TimeD  (None, 25, 16, 16, 32)    4640
#  istributed)
#
#  time_distributed_16 (TimeD  (None, 25, 4, 4, 32)      0
#  istributed)
#
#  time_distributed_17 (TimeD  (None, 25, 4, 4, 32)      0
#  istributed)
#
#  time_distributed_18 (TimeD  (None, 25, 4, 4, 64)      18496
#  istributed)
#
#  time_distributed_19 (TimeD  (None, 25, 2, 2, 64)      0
#  istributed)
#
#  time_distributed_20 (TimeD  (None, 25, 2, 2, 64)      0
#  istributed)
#
#  time_distributed_21 (TimeD  (None, 25, 2, 2, 64)      36928
#  istributed)
#
#  time_distributed_22 (TimeD  (None, 25, 1, 1, 64)      0
#  istributed)
#
#  time_distributed_23 (TimeD  (None, 25, 64)            0
#  istributed)
#
#  lstm_1 (LSTM)               (None, 32)                12416
#
#  dense_1 (Dense)             (None, 7)                 231
#
# =================================================================
# Total params: 73159 (285.78 KB)
# Trainable params: 73159 (285.78 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model Created Successfully!

# %%
# Plot the structure of the contructed LRCN model.
plot_model(LRCN_model, to_file = 'LRCN_model_structure_plot.png', show_shapes = True, show_layer_names = True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
# Create an Instance of Early Stopping Callback.
early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 15, mode = 'min', restore_best_weights = True)
 
# Compile the model and specify loss function, optimizer and metrics to the model.
LRCN_model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ["accuracy"])

# Start training the model.
LRCN_model_training_history = LRCN_model.fit(x = features_train, y = labels_train, epochs = 70, batch_size = 4 ,
                                             shuffle = True, validation_split = 0.2, callbacks = [early_stopping_callback])
# Out:
# Epoch 1/70
# 167/167 [==============================] - 6s 23ms/step - loss: 1.9561 - accuracy: 0.1409 - val_loss: 1.9516 - val_accuracy: 0.0719
# Epoch 2/70
# 167/167 [==============================] - 3s 16ms/step - loss: 1.9288 - accuracy: 0.1619 - val_loss: 1.8921 - val_accuracy: 0.2515
# Epoch 3/70
# 167/167 [==============================] - 3s 16ms/step - loss: 1.8001 - accuracy: 0.2684 - val_loss: 1.6771 - val_accuracy: 0.2874
# Epoch 4/70
# 167/167 [==============================] - 3s 16ms/step - loss: 1.4921 - accuracy: 0.4393 - val_loss: 1.4618 - val_accuracy: 0.4311
# Epoch 5/70
# 167/167 [==============================] - 3s 16ms/step - loss: 1.3219 - accuracy: 0.4858 - val_loss: 1.1682 - val_accuracy: 0.5329
# Epoch 6/70
# 167/167 [==============================] - 3s 16ms/step - loss: 1.0578 - accuracy: 0.5862 - val_loss: 0.9061 - val_accuracy: 0.6707
# Epoch 7/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.7765 - accuracy: 0.7121 - val_loss: 0.8144 - val_accuracy: 0.6766
# Epoch 8/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.6738 - accuracy: 0.7451 - val_loss: 0.6710 - val_accuracy: 0.7425
# Epoch 9/70
# 167/167 [==============================] - 3s 15ms/step - loss: 0.5422 - accuracy: 0.7976 - val_loss: 0.4379 - val_accuracy: 0.8503
# Epoch 10/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.5030 - accuracy: 0.8261 - val_loss: 0.7847 - val_accuracy: 0.7784
# Epoch 11/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.4190 - accuracy: 0.8591 - val_loss: 0.3708 - val_accuracy: 0.8503
# Epoch 12/70
# 167/167 [==============================] - 2s 14ms/step - loss: 0.2607 - accuracy: 0.9220 - val_loss: 0.2110 - val_accuracy: 0.9341
# Epoch 13/70
# 167/167 [==============================] - 2s 14ms/step - loss: 0.3174 - accuracy: 0.8951 - val_loss: 0.3792 - val_accuracy: 0.8743
# Epoch 14/70
# 167/167 [==============================] - 3s 15ms/step - loss: 0.1589 - accuracy: 0.9475 - val_loss: 0.2041 - val_accuracy: 0.9401
# Epoch 15/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.1587 - accuracy: 0.9535 - val_loss: 0.2329 - val_accuracy: 0.9222
# Epoch 16/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.4644 - accuracy: 0.8756 - val_loss: 0.2589 - val_accuracy: 0.9162
# Epoch 17/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.1442 - accuracy: 0.9520 - val_loss: 0.1341 - val_accuracy: 0.9461
# Epoch 18/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0804 - accuracy: 0.9835 - val_loss: 0.0726 - val_accuracy: 0.9820
# Epoch 19/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0691 - accuracy: 0.9820 - val_loss: 0.3573 - val_accuracy: 0.8743
# Epoch 20/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0929 - accuracy: 0.9640 - val_loss: 0.0548 - val_accuracy: 0.9820
# Epoch 21/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0973 - accuracy: 0.9685 - val_loss: 0.1434 - val_accuracy: 0.9401
# Epoch 22/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.2889 - accuracy: 0.9115 - val_loss: 0.2650 - val_accuracy: 0.8862
# Epoch 23/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.1121 - accuracy: 0.9640 - val_loss: 0.0282 - val_accuracy: 0.9940
# Epoch 24/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0388 - accuracy: 0.9895 - val_loss: 0.0291 - val_accuracy: 0.9940
# Epoch 25/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0321 - accuracy: 0.9925 - val_loss: 0.0522 - val_accuracy: 0.9880
# Epoch 26/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.1560 - accuracy: 0.9505 - val_loss: 0.1455 - val_accuracy: 0.9641
# Epoch 27/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0846 - accuracy: 0.9760 - val_loss: 0.0661 - val_accuracy: 0.9760
# Epoch 28/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0256 - accuracy: 0.9940 - val_loss: 0.1240 - val_accuracy: 0.9581
# Epoch 29/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.1148 - accuracy: 0.9610 - val_loss: 0.0674 - val_accuracy: 0.9820
# Epoch 30/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0349 - accuracy: 0.9910 - val_loss: 0.0152 - val_accuracy: 1.0000
# Epoch 31/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0228 - accuracy: 0.9910 - val_loss: 0.0178 - val_accuracy: 0.9940
# Epoch 32/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0243 - accuracy: 0.9925 - val_loss: 0.0255 - val_accuracy: 0.9940
# Epoch 33/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0390 - accuracy: 0.9910 - val_loss: 0.0131 - val_accuracy: 1.0000
# Epoch 34/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.2786 - accuracy: 0.9205 - val_loss: 0.0657 - val_accuracy: 0.9760
# Epoch 35/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0234 - accuracy: 0.9970 - val_loss: 0.0185 - val_accuracy: 1.0000
# Epoch 36/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0202 - accuracy: 0.9970 - val_loss: 0.0107 - val_accuracy: 1.0000
# Epoch 37/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 38/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 39/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 40/70
# 167/167 [==============================] - 3s 15ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 41/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 42/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 43/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 44/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 45/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0267 - accuracy: 0.9940 - val_loss: 0.0107 - val_accuracy: 1.0000
# Epoch 46/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.1483 - accuracy: 0.9535 - val_loss: 0.0505 - val_accuracy: 0.9880
# Epoch 47/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.1207 - accuracy: 0.9685 - val_loss: 0.0811 - val_accuracy: 0.9760
# Epoch 48/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0837 - accuracy: 0.9760 - val_loss: 0.0836 - val_accuracy: 0.9760
# Epoch 49/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0482 - accuracy: 0.9865 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 50/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0209 - accuracy: 0.9955 - val_loss: 0.0389 - val_accuracy: 0.9940
# Epoch 51/70
# 167/167 [==============================] - 2s 15ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0379 - val_accuracy: 0.9940
# Epoch 52/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0386 - val_accuracy: 0.9940
# Epoch 53/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0333 - val_accuracy: 0.9940
# Epoch 54/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0305 - val_accuracy: 0.9940
# Epoch 55/70
# 167/167 [==============================] - 3s 15ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 56/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 57/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 58/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 59/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9940
# Epoch 60/70
# 167/167 [==============================] - 3s 15ms/step - loss: 0.0659 - accuracy: 0.9850 - val_loss: 0.3923 - val_accuracy: 0.8623
# Epoch 61/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.1951 - accuracy: 0.9415 - val_loss: 0.0582 - val_accuracy: 0.9880
# Epoch 62/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0372 - accuracy: 0.9880 - val_loss: 0.0611 - val_accuracy: 0.9820
# Epoch 63/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0818 - accuracy: 0.9760 - val_loss: 0.0239 - val_accuracy: 0.9820
# Epoch 64/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0283 - accuracy: 0.9925 - val_loss: 0.0143 - val_accuracy: 0.9940
# Epoch 65/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0114 - accuracy: 0.9985 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 66/70
# 167/167 [==============================] - 3s 15ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 67/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0823 - val_accuracy: 0.9760
# Epoch 68/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0079 - accuracy: 0.9985 - val_loss: 0.0170 - val_accuracy: 0.9940
# Epoch 69/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 70/70
# 167/167 [==============================] - 3s 16ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000

# %%
# Evaluate the trained model.
model_evaluation_history = LRCN_model.evaluate(features_test, labels_test)
# Out:
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0593 - accuracy: 0.9857

# %%
# Get the loss and accuracy from model_evaluation_history.
model_evaluation_loss, model_evaluation_accuracy = model_evaluation_history

# Define the string date format.
# Get the current Date and Time in a DateTime Object.
# Convert the DateTime object to string according to the style mentioned in date_time_format string.
date_time_format = '%Y_%m_%d__%H_%M_%S'
current_date_time_dt = dt.datetime.now()
current_date_time_string = dt.datetime.strftime(current_date_time_dt, date_time_format)
    
# Define a useful name for our model to make it easy for us while navigating through multiple saved models.
model_file_name = f'LRCN_model___Date_Time_{current_date_time_string}___Loss_{model_evaluation_loss}___Accuracy_{model_evaluation_accuracy}.h5'

# Save the Model.
LRCN_model.save(model_file_name)

# %%
# Visualize the training and validation loss metrices.
plot_metric(LRCN_model_training_history, 'loss', 'val_loss', 'Total Loss vs Total Validation Loss')

# %%
# Visualize the training and validation accuracy metrices.
plot_metric(LRCN_model_training_history, 'accuracy', 'val_accuracy', 'Total Accuracy vs Total Validation Accuracy')
